# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Conv1D, MaxPooling1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
import re

# %%
df = pd.read_csv('dataset/datafinal.csv', encoding='latin-1')
df
# Out:
#        Unnamed: 0                                               text  author  \
# 0               0  ou have time to listen i will give you the ent...       1
# 1               1  wish for solitude he was twenty years of age a...       1
# 2               2  and the skirt blew in perfect freedom about th...       1
# 3               3  of san and the rows of shops opposite impresse...       1
# 4               4  an hour s walk was as tiresome as three in a s...       1
# ...           ...                                                ...     ...
# 53673       53673  after surrounding and searching the whole plac...      50
# 53674       53674  giant who could make a young earthquake or a w...      50
# 53675       53675  waters of the lake at the bottom of the hill c...      50
# 53676       53676  fingers and thumb in it exactly as it came out...      50
# 53677       53677  giant s sake he won t meet with for if he does...      50
#
#                                        text no stopwords  \
# 0      ou time listen give entire story say may form ...
# 1      wish solitude twenty years age possession perf...
# 2      skirt blow perfect freedom upper part wear hat...
# 3      san row shop opposite impress upon vision last...
# 4      hour walk tiresome three sensible english town...
# ...                                                  ...
# 53673  surround search whole place could discover tra...
# 53674  giant could make young earthquake angry accord...
# 53675  water lake bottom hill curl kindness sympathy ...
# 53676  finger thumb exactly come hand never mind say ...
# 53677  giant sake meet fin make well say seek twelve ...
#
#                                    top text no stopwords
# 0      one time row give may city boat effect interes...
# 1      one time row give may city boat effect interes...
# 2      one time row give may city boat effect interes...
# 3      one time row give may city boat effect interes...
# 4      one time row give may city boat effect interes...
# ...                                                  ...
# 53673  one time row give may city boat effect interes...
# 53674  one time row give may city boat effect interes...
# 53675  one time row give may city boat effect interes...
# 53676  one time row give may city boat effect interes...
# 53677  one time row give may city boat effect interes...
#
# [53678 rows x 5 columns]

# %%
df['text'] = df['text no stopwords']
df
# Out:
#        Unnamed: 0                                               text  author  \
# 0               0  ou time listen give entire story say may form ...       1
# 1               1  wish solitude twenty years age possession perf...       1
# 2               2  skirt blow perfect freedom upper part wear hat...       1
# 3               3  san row shop opposite impress upon vision last...       1
# 4               4  hour walk tiresome three sensible english town...       1
# ...           ...                                                ...     ...
# 53673       53673  surround search whole place could discover tra...      50
# 53674       53674  giant could make young earthquake angry accord...      50
# 53675       53675  water lake bottom hill curl kindness sympathy ...      50
# 53676       53676  finger thumb exactly come hand never mind say ...      50
# 53677       53677  giant sake meet fin make well say seek twelve ...      50
#
#                                        text no stopwords  \
# 0      ou time listen give entire story say may form ...
# 1      wish solitude twenty years age possession perf...
# 2      skirt blow perfect freedom upper part wear hat...
# 3      san row shop opposite impress upon vision last...
# 4      hour walk tiresome three sensible english town...
# ...                                                  ...
# 53673  surround search whole place could discover tra...
# 53674  giant could make young earthquake angry accord...
# 53675  water lake bottom hill curl kindness sympathy ...
# 53676  finger thumb exactly come hand never mind say ...
# 53677  giant sake meet fin make well say seek twelve ...
#
#                                    top text no stopwords
# 0      one time row give may city boat effect interes...
# 1      one time row give may city boat effect interes...
# 2      one time row give may city boat effect interes...
# 3      one time row give may city boat effect interes...
# 4      one time row give may city boat effect interes...
# ...                                                  ...
# 53673  one time row give may city boat effect interes...
# 53674  one time row give may city boat effect interes...
# 53675  one time row give may city boat effect interes...
# 53676  one time row give may city boat effect interes...
# 53677  one time row give may city boat effect interes...
#
# [53678 rows x 5 columns]

# %%
max_words = 100000
max_length = 1000
embedding_dim = 100
tokenizer = Tokenizer(num_words=max_words, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(df.text)
print("tokens:", tokenizer.word_index)
# Out:
# tokens: {'ã¢': 1, 'say': 2, 'one': 3, 'would': 4, 'go': 5, 'know': 6, 'come': 7, 'make': 8, 'think': 9, 'mr': 10, 'could': 11, 'see': 12, 'man': 13, 'time': 14, 'look': 15, 'take': 16, 'like': 17, 'little': 18, 'upon': 19, 'well': 20, 'good': 21, 'give': 22, 'never': 23, 'much': 24, 'get': 25, 'hand': 26, 'must': 27, 'tell': 28, 'great': 29, 'old': 30, 'two': 31, 'mrs': 32, 'find': 33, 'even': 34, 'day': 35, 'eye': 36, 'may': 37, 'leave': 38, 'way': 39, 'life': 40, 'us': 41, 'might': 42, 'first': 43, 'long': 44, 'seem': 45, 'back': 46, 'hear': 47, 'every': 48, 'men': 49, 'house': 50, 'though': 51, 'place': 52, 'away': 53, 'love': 54, 'shall': 55, 'without': 56, 'nothing': 57, 'head': 58, 'face': 59, 'last': 60, 'young': 61, 'many': 62, 'turn': 63, 'speak': 64, 'ever': 65, 'yet': 66, 'work': 67, 'sir': 68, 'ask': 69, 'call': 70, 'mind': 71, 'miss': 72, 'still': 73, 'word': 74, 'room': 75, 'new': 76, 'mean': 77, 'stand': 78, 'want': 79, 'put': 80, 'let': 81, 'feel': 82, 'night': 83, 'people': 84, 'begin': 85, 'father': 86, 'always': 87, 'live': 88, 'another': 89, 'right': 90, 'keep': 91, 'mother': 92, 'sit': 93, 'thing': 94, 'part': 95, 'world': 96, 'quite': 97, 'woman': 98, 'bring': 99, 'saw': 100, 'return': 101, 'dear': 102, 'home': 103, 'heart': 104, 'better': 105, 'three': 106, 'oh': 107, 'do': 108, 'pass': 109, 'side': 110, 'cry': 111, 'lady': 112, 'yes': 113, 'things': 114, 'light': 115, 'years': 116, 'half': 117, 'poor': 118, 'name': 119, 'wish': 120, 'use': 121, 'hold': 122, 'answer': 123, 'something': 124, 'moment': 125, 'open': 126, 'enough': 127, 'write': 128, 'far': 129, 'end': 130, 'talk': 131, 'walk': 132, 'state': 133, 'meet': 134, 'n': 135, 'soon': 136, 'become': 137, 'door': 138, 'believe': 139, 'lay': 140, 'reply': 141, 'show': 142, 'present': 143, 'felt': 144, 'run': 145, 'course': 146, 'among': 147, 'perhaps': 148, 'however': 149, 'matter': 150, 'follow': 151, 'whole': 152, 'rather': 153, 'set': 154, 'voice': 155, 'draw': 156, 'letter': 157, 'morning': 158, 'round': 159, 'till': 160, 'water': 161, 'indeed': 162, 'sure': 163, 'book': 164, 'e': 165, 'white': 166, 'best': 167, 'rise': 168, 'try': 169, 'interest': 170, 'friend': 171, 'days': 172, 'l': 173, 'point': 174, 'break': 175, 'wife': 176, 'arm': 177, 'almost': 178, 'j': 179, 'die': 180, 'since': 181, 'r': 182, 'next': 183, 'anything': 184, 'god': 185, 'read': 186, 'hope': 187, 'kind': 188, 'suppose': 189, 'country': 190, 'together': 191, 'also': 192, 'lie': 193, 'appear': 194, 'cannot': 195, 'send': 196, 'less': 197, 'understand': 198, 'smile': 199, 'grow': 200, 'nature': 201, 'rest': 202, 'child': 203, 'form': 204, 'f': 205, 'small': 206, 'lose': 207, 'money': 208, 'bear': 209, 'whose': 210, 'power': 211, 'girl': 212, 'air': 213, 'question': 214, 'fire': 215, 'true': 216, 'wait': 217, 'help': 218, 'spirit': 219, 'change': 220, 'order': 221, 'least': 222, 'h': 223, 'care': 224, 'fall': 225, 'case': 226, 'full': 227, 'marry': 228, 'horse': 229, 'john': 230, 'high': 231, 'really': 232, 'feet': 233, 'hour': 234, 'carry': 235, 'tree': 236, 'often': 237, 'sense': 238, 'lead': 239, 'thus': 240, 'laugh': 241, 'land': 242, 'close': 243, 'remember': 244, 'reason': 245, 'boy': 246, 'pay': 247, 'along': 248, 'alone': 249, 'play': 250, 'others': 251, 'business': 252, 'lord': 253, 'family': 254, 'manner': 255, 'remain': 256, 'whether': 257, 'c': 258, 'add': 259, 'de': 260, 'bad': 261, 'near': 262, 'large': 263, 'black': 264, 'general': 265, 'death': 266, 'five': 267, 'within': 268, 'b': 269, 'fear': 270, 'subject': 271, 'wonder': 272, 'enter': 273, 'four': 274, 'receive': 275, 'doubt': 276, 'table': 277, 'year': 278, 'certain': 279, 'throw': 280, 'women': 281, 'dead': 282, 'please': 283, 'towards': 284, 'behind': 285, 'hard': 286, 'move': 287, 'short': 288, 'need': 289, 'son': 290, 'king': 291, 'husband': 292, 'master': 293, 'u': 294, 'hundred': 295, 'stop': 296, 'children': 297, 'sort': 298, 'sea': 299, 'watch': 300, 'gentleman': 301, 'forget': 302, 'body': 303, 'v': ...

# %% [markdown]
# "data = pad_sequences(data, max_length)" in this line, it should be max_length, i used max_words

# %%
labels = to_categorical(df.author - 1)
data = tokenizer.texts_to_sequences(df.text)
data = pad_sequences(data, max_length)
train_data, test_data, train_label, test_label = train_test_split(data, labels, test_size = 0.10, random_state = 30)

# %%
model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=train_data.shape[1]))
model.add(Conv1D(filters = 32, kernel_size = 5, padding="same", activation="relu"))
model.add(MaxPooling1D(pool_size = 2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(50, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 100)         10000000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1000, 32)          16032
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               53200
# _________________________________________________________________
# dense (Dense)                (None, 50)                5050
# =================================================================
# Total params: 10,074,282
# Trainable params: 10,074,282
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epochs = 5
batch_size = 64
model.fit(train_data, train_label, epochs=epochs, batch_size=batch_size,validation_split=0.1)
# Out:
# Epoch 1/5
# 234/680 [=========>....................] - ETA: 6:27 - loss: 3.4354 - accuracy: 0.1325
